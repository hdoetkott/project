# %% [markdown]
# <font color='red'> Sprint 4 Project

# %% [markdown]
# <font color='red'>the plan for this project
# 1. create streamlit with render, add a streamlit configuration file to git repository at .streamlit/config.toml
#
# 2. create account on render.com and create a new web service
# 3. Create a new web service linked to Github repository
# 4. Configure the new Render web service. at Build Command, add pip install streamlit & pip install -r requirements.txt
# add Start Command, add: streamlit run app.py
# 5. Deploy to Render,
# 6. Verify application is accessible at the following URL: https://sprint4-1kgb.onrender.com/
#     <font color='red'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns


vehicles = pd.read_csv('/Users/hannysetiawan/Downloads/vehicles_us.csv', sep=',')

# %% [markdown]
# <font color='red'> display table

# %%
vehicles
# Out:
#        price  model_year           model  condition  cylinders fuel  odometer  \
# 0       9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1      25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2       5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3       1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4      14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
# ...      ...         ...             ...        ...        ...  ...       ...
# 51520   9249      2013.0   nissan maxima   like new        6.0  gas   88136.0
# 51521   2700      2002.0     honda civic    salvage        4.0  gas  181500.0
# 51522   3950      2009.0  hyundai sonata  excellent        4.0  gas  128000.0
# 51523   7455      2013.0  toyota corolla       good        4.0  gas  139573.0
# 51524   6300      2014.0   nissan altima       good        4.0  gas       NaN
#
#       transmission    type paint_color  is_4wd date_posted  days_listed
# 0        automatic     SUV         NaN     1.0  2018-06-23           19
# 1        automatic  pickup       white     1.0  2018-10-19           50
# 2        automatic   sedan         red     NaN  2019-02-07           79
# 3        automatic  pickup         NaN     NaN  2019-03-22            9
# 4        automatic   sedan       black     NaN  2019-04-02           28
# ...            ...     ...         ...     ...         ...          ...
# 51520    automatic   sedan       black     NaN  2018-10-03           37
# 51521    automatic   sedan       white     NaN  2018-11-14           22
# 51522    automatic   sedan        blue     NaN  2018-11-15           32
# 51523    automatic   sedan       black     NaN  2018-07-02           71
# 51524    automatic   sedan         NaN     NaN  2018-06-05           10
#
# [51525 rows x 13 columns]

# %%
vehicles.describe().T.astype(int)
# Out:
#              count    mean    std   min    25%     50%     75%     max
# price        51525   12132  10040     1   5000    9000   16839  375000
# model_year   47906    2009      6  1908   2006    2011    2014    2019
# cylinders    46265       6      1     3      4       6       8      12
# odometer     43633  115553  65094     0  70000  113000  155000  990000
# is_4wd       25572       1      0     1      1       1       1       1
# days_listed  51525      39     28     0     19      33      53     271

# %%
vehicles.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <font color='red'>no duplicate found

# %%
len(vehicles[vehicles.isnull().any(axis=1)])/len(vehicles)
# Out:
# 0.7117515769044154

# %% [markdown]
# <font color='red'>70% of rows has at least one missing value

# %%
v_nan = vehicles.dropna()
v_nan
# Out:
#        price  model_year                       model  condition  cylinders  \
# 5      14990      2014.0                chrysler 300  excellent        6.0
# 7      15990      2013.0                 honda pilot  excellent        6.0
# 10     19500      2011.0    chevrolet silverado 1500  excellent        8.0
# 14     12990      2009.0                   gmc yukon  excellent        8.0
# 16     14990      2010.0                    ram 1500  excellent        8.0
# ...      ...         ...                         ...        ...        ...
# 51494   7999      2009.0           chevrolet equinox  excellent        6.0
# 51500   6995      2012.0               buick enclave  excellent        6.0
# 51509   5980      2010.0              subaru impreza  excellent        4.0
# 51513  17999      2014.0                    ram 1500   like new        8.0
# 51515  12000      2005.0  chevrolet silverado 2500hd       good        8.0
#
#          fuel  odometer transmission       type paint_color  is_4wd  \
# 5         gas   57954.0    automatic      sedan       black     1.0
# 7         gas  109473.0    automatic        SUV       black     1.0
# 10        gas  128413.0    automatic     pickup       black     1.0
# 14        gas  132285.0    automatic        SUV       black     1.0
# 16        gas  130725.0    automatic     pickup         red     1.0
# ...       ...       ...          ...        ...         ...     ...
# 51494     gas   95021.0    automatic        SUV      silver     1.0
# 51500     gas  157000.0    automatic        SUV       white     1.0
# 51509     gas  121778.0       manual  hatchback       white     1.0
# 51513     gas  154000.0    automatic     pickup       white     1.0
# 51515  diesel  228000.0    automatic     pickup      silver     1.0
#
#       date_posted  days_listed
# 5      2018-06-20           15
# 7      2019-01-07           68
# 10     2018-09-17           38
# 14     2019-01-31           24
# 16     2018-12-30           13
# ...           ...          ...
# 51494  2019-01-03            8
# 51500  2018-08-04           17
# 51509  2019-01-10            8
# 51513  2018-06-21           11
# 51515  2018-08-18           52
#
# [14852 rows x 13 columns]

# %%
v_nan.isnull().sum()
# Out:
# price           0
# model_year      0
# model           0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# transmission    0
# type            0
# paint_color     0
# is_4wd          0
# date_posted     0
# days_listed     0
# dtype: int64

# %% [markdown]
# <font color='red'> no missing value found

# %%
v_nan['model_year'] = v_nan['model_year'].astype(int)
# Out:
# /var/folders/x0/f8xnsctx7fl2t7dlx2p8nztr0000gn/T/ipykernel_3111/3536332850.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   v_nan['model_year'] = v_nan['model_year'].astype(int)

# %%
v_nan['odometer'] = v_nan['odometer'].astype(int)
# Out:
# /var/folders/x0/f8xnsctx7fl2t7dlx2p8nztr0000gn/T/ipykernel_3111/1771274364.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   v_nan['odometer'] = v_nan['odometer'].astype(int)

# %%
v_nan['cylinders'] = v_nan['cylinders'].astype(int)
# Out:
# /var/folders/x0/f8xnsctx7fl2t7dlx2p8nztr0000gn/T/ipykernel_3111/616781548.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   v_nan['cylinders'] = v_nan['cylinders'].astype(int)

# %%
v_nan['is_4wd'] = v_nan['is_4wd'].astype(int)
# Out:
# /var/folders/x0/f8xnsctx7fl2t7dlx2p8nztr0000gn/T/ipykernel_3111/2560776680.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   v_nan['is_4wd'] = v_nan['is_4wd'].astype(int)

# %% [markdown]
# <font color='red'>type to interger

# %%
v_nan
# Out:
#        price  model_year                       model  condition  cylinders  \
# 5      14990        2014                chrysler 300  excellent          6
# 7      15990        2013                 honda pilot  excellent          6
# 10     19500        2011    chevrolet silverado 1500  excellent          8
# 14     12990        2009                   gmc yukon  excellent          8
# 16     14990        2010                    ram 1500  excellent          8
# ...      ...         ...                         ...        ...        ...
# 51494   7999        2009           chevrolet equinox  excellent          6
# 51500   6995        2012               buick enclave  excellent          6
# 51509   5980        2010              subaru impreza  excellent          4
# 51513  17999        2014                    ram 1500   like new          8
# 51515  12000        2005  chevrolet silverado 2500hd       good          8
#
#          fuel  odometer transmission       type paint_color  is_4wd  \
# 5         gas     57954    automatic      sedan       black       1
# 7         gas    109473    automatic        SUV       black       1
# 10        gas    128413    automatic     pickup       black       1
# 14        gas    132285    automatic        SUV       black       1
# 16        gas    130725    automatic     pickup         red       1
# ...       ...       ...          ...        ...         ...     ...
# 51494     gas     95021    automatic        SUV      silver       1
# 51500     gas    157000    automatic        SUV       white       1
# 51509     gas    121778       manual  hatchback       white       1
# 51513     gas    154000    automatic     pickup       white       1
# 51515  diesel    228000    automatic     pickup      silver       1
#
#       date_posted  days_listed
# 5      2018-06-20           15
# 7      2019-01-07           68
# 10     2018-09-17           38
# 14     2019-01-31           24
# 16     2018-12-30           13
# ...           ...          ...
# 51494  2019-01-03            8
# 51500  2018-08-04           17
# 51509  2019-01-10            8
# 51513  2018-06-21           11
# 51515  2018-08-18           52
#
# [14852 rows x 13 columns]

# %% [markdown]
# <font color='red'>display table all with int

# %%
print(v_nan.mean())
print(v_nan.median())
# Out:
# price           15446.921155
# model_year       2010.052586
# cylinders           6.798950
# odometer       117713.691287
# is_4wd              1.000000
# days_listed        39.863520
# dtype: float64
# price           13500.0
# model_year       2011.0
# cylinders           8.0
# odometer       115665.5
# is_4wd              1.0
# days_listed        34.0
# dtype: float64
# /var/folders/x0/f8xnsctx7fl2t7dlx2p8nztr0000gn/T/ipykernel_3111/3179486678.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(v_nan.mean())
# /var/folders/x0/f8xnsctx7fl2t7dlx2p8nztr0000gn/T/ipykernel_3111/3179486678.py:2: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   print(v_nan.median())

# %% [markdown]
# <font color='red'>use median

# %%
fig, ax = plt.subplots(figsize=(8,7))
ax = sns.histplot(v_nan, x="model", 
                  hue="condition")

# %% [markdown]
# <font color='red'>visualization histogram

# %%
fig, ax = plt.subplots(figsize=(8,7))
ax = sns.histplot(v_nan, x="price", 
                  hue="model")

# %%
v_nan.plot(kind = 'scatter', 
                          title = 'vehicles',
                          x = 'model_year',
                          y = 'price',
                          xlabel = 'model_year',
                          ylabel = 'price'
                          )
plt.style.use('dark_background')
plt.show()

# %% [markdown]
# <font color='red'>visualization scatter
